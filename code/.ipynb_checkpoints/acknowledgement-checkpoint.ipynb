# %%
import time
import pickle
import requests
import numpy as np
import pandas as pd

import config
from crawler import *

# %%
meta_data = get_stock_meta_data()
# Out:
# downloading data from website
# creating dataframe

# %%
pd.set_option('display.max_rows', None)
meta_data
# Out:
#              code     name   listed_date industry_type
# 0            1101       台泥    1962/02/09          水泥工業
# 1            1102       亞泥    1962/06/08          水泥工業
# 2            1103       嘉泥    1969/11/14          水泥工業
# 3            1104       環泥    1971/02/01          水泥工業
# 4            1108       幸福    1990/06/06          水泥工業
# 5            1109       信大    1991/12/05          水泥工業
# 6            1110       東泥    1994/10/22          水泥工業
# 7            1201       味全    1962/02/09          食品工業
# 8            1203       味王    1964/08/24          食品工業
# 9            1210       大成    1978/05/20          食品工業
# 10           1213       大飲    1981/04/10          食品工業
# 11           1215       卜蜂    1987/07/27          食品工業
# 12           1216       統一    1987/12/28          食品工業
# 13           1217      愛之味    1989/10/28          食品工業
# 14           1218       泰山    1989/11/11          食品工業
# 15           1219       福壽    1990/12/01          食品工業
# ...

# %%
meta_data.to_csv('../data_sample/stock_meta_data.csv', index=False)

# %%
data = query_mops(109, 'profit_loss')

# data[i][j]
# i: season
# j:
#    1: bank
#    3: standard
#    4: holdings
#    5: insurance
#    6: other
# Out:
# 0
# 1
# 2
# 3

# %%
norm = merge_by_season_per_year(data, config.profit_loss_col['standard'], 3, 109)

# %%
norm
# Out:
# {'營業收入':      公司代號     公司名稱        109_1         109_2         109_3       109_4
#  0    1101       台泥   21976200.0  5.243983e+07  8.224849e+07   114367247
#  1    1102       亞泥   13138882.0  3.382809e+07  5.456417e+07    78240880
#  2    1103       嘉泥     495334.0  9.923190e+05  1.481489e+06     2058417
#  3    1104       環泥    1253758.0  2.591631e+06  3.886551e+06     5426217
#  4    1108       幸福    1104720.0  2.226696e+06  3.358346e+06     4530172
#  5    1109       信大    1165580.0  3.255948e+06  5.213429e+06     7593294
#  6    1110       東泥     387944.0  7.704910e+05  1.137023e+06     1590986
#  7    1201       味全    3974417.0  8.591862e+06  1.394205e+07    18650871
#  8    1203       味王    1583090.0  3.019057e+06  4.549315e+06     6043700
#  9    1210       大成   18331788.0  3.748326e+07  5.825267e+07    81650892
#  10   1213       大飲      80065.0  1.664320e+05  3.265320e+05      409612
#  11   1215       卜蜂    5241193.0  1.066909e+07  1.636671e+07    22189635
# ...

# %%
dividend = query_dividend(6491)
dividend
# Out:
# 108
# 107
# 105
#   year distribute_date  cash_dividend  stock_dividend  total  company_code
# 0  108      2020-07-09            2.5             0.0    2.5          6491
# 1  107      2019-08-16            1.5             0.0    1.5          6491
# 2  105      2017-09-06            1.0             0.0    1.0          6491

# %%
financial, season = query_mops(109, 'cash_flow', 1713, 2)
financial
# Out:
# [[                                0
#   0  「投資人若需了解更詳細資訊可至XBRL資訊平台或電子書查詢」
#   1             本公司採 月制會計年度(空白表曆年制),
#                      民國109年第1季                                              \
#                       單位：新台幣仟元
#                           會計項目 109年01月01日至109年03月31日 108年01月01日至108年03月31日
#             Unnamed: 0_level_3                    金額                    金額
#   0              營業活動之現金流量－間接法                   NaN                   NaN
#   1             繼續營業單位稅前淨利（淨損）               16692.0               19592.0
#   2                 本期稅前淨利（淨損）               16692.0               19592.0
#   3                       折舊費用                4892.0                4738.0
#   4                       攤銷費用                   4.0                   4.0
#   5                       利息收入                -926.0                -907.0
#   6   採用權益法認列之關聯企業及合資損失（利益）之份額              -10657.0              -16405.0
#   7                   收益費損項目合計               -6687.0              -12570.0
# ...

# %%
summary_cashflow(financial, 109, season)
# Out:
# 0     營運產生之現金流入（流出） 營業活動之淨現金流入（流出） 取得不動產、廠房及設備 投資活動之淨現金流入（流出）
# 109_1         -5209          -4410        -717          -3093
# 109_2        -11829         -10796       -2013         -34411
# 109_3          9305         -37682       -3341         -44458
# 109_4         11591         -34980       -5213         -57212

# %%
stocks = pd.read_csv('../data_sample/stock_meta_data.csv')
stocks
# Out:
#      code  name listed_date industry_type
# 0    1101    台泥  1962/02/09          水泥工業
# 1    1102    亞泥  1962/06/08          水泥工業
# 2    1103    嘉泥  1969/11/14          水泥工業
# 3    1104    環泥  1971/02/01          水泥工業
# 4    1108    幸福  1990/06/06          水泥工業
# ..    ...   ...         ...           ...
# 947  9944    新麗  2002/08/26           其他業
# 948  9945   潤泰新  1992/04/30           其他業
# 949  9946  三發地產  2013/09/17         建材營造業
# 950  9955    佳龍  2008/01/21           其他業
# 951  9958   世紀鋼  2008/03/12          鋼鐵工業
#
# [952 rows x 4 columns]

# %%
previous = pickle.load(open('../data_sample/cashflow_tmp_108.pkl', 'rb'))#.keys()
len(previous)
# Out:
# 360

# %%
for i in previous:
    if len(previous[i]) != 4:
        print(i)
#         df, seasons = query_mops(109, 'cash_flow', i, 2)
#         previous[i] = summary_cashflow(df, 109, seasons)
#         time.sleep(20)
# Out:
# 2211
# 6515
# 6743
# 6768
# 6776
# 6781

# %%
with open(f'../data_sample/cashflow_tmp.pkl', 'wb') as f:
    pickle.dump(previous, f)

# %%
cols = list(config.cashflow_col.keys())
cols
# Out:
# ['營運產生之現金流入（流出）',
#  '營業活動之淨現金流入（流出）',
#  '取得不動產、廠房及設備',
#  '投資活動之淨現金流入（流出）',
#  '籌資活動之淨現金流入（流出）']

# %%
merged_df = pd.concat([previous[2330][cols[0]], previous[2379][cols[0]]], axis=1)
merged_df.columns = [2330, 2379]
merged_df.T
# Out:
#             109_1        109_2        109_3        109_4
# 2330  2.04408e+08  4.05907e+08  6.14433e+08  8.74029e+08
# 2379       152056  3.12966e+06  9.03664e+06   1.4613e+07

# %%
pd.read_csv('../data_sample/real_estate.csv')
# Out:
#      company      109_1      109_2      109_3      109_4
# 0       1101 -2025760.0 -3847205.0 -6112067.0 -9572441.0
# 1       1102 -1684288.0 -3146702.0 -4296511.0 -6293577.0
# 2       1103  -503104.0  -549877.0  -723525.0  -746786.0
# 3       1104   -35028.0   -72977.0  -124151.0  -168830.0
# 4       1108    -5427.0    -7548.0  -460546.0  -654165.0
# ..       ...        ...        ...        ...        ...
# 908     9944   -71715.0  -133224.0  -223006.0  -304809.0
# 909     9945  -196866.0  -361130.0  -454756.0  -644390.0
# 910     9946        NaN        0.0     -715.0     -875.0
# 911     9955    -5896.0   -10517.0   -23427.0   -31618.0
# 912     9958  -231888.0  -600108.0 -1107360.0 -2216895.0
#
# [913 rows x 5 columns]
